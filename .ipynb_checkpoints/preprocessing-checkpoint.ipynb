# %%
from utils.utils import *
import pandas as pd
# %load_ext autoreload
# %autoreload 2
from IPython.display import display, HTML
from utils.lta_omv_scraper import *
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import MultiLabelBinarizer
import numpy as np
import time
from datetime import datetime
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
import os
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
orig_df = pd.read_csv(r"./dataset/train.csv")
test_df = pd.read_csv(r"./dataset/test.csv")

# clean model
orig_df['model'] = orig_df['model'].apply(lambda x:x.replace('(', ''))
orig_df['reg_date_dt'] = orig_df['reg_date'].apply(lambda x: datetime.strptime(x, "%d-%b-%Y"))
orig_df['reg_date_year'] = orig_df['reg_date_dt'].apply(lambda x:x.year)
orig_df['reg_date_month'] = orig_df['reg_date_dt'].apply(lambda x:x.month)

# %%
train_df, val_df = train_test_split(orig_df, test_size=0.2, random_state=42, shuffle=True)

# %% [markdown]
# ### Fill missing 'make' info from title

# %%
make_ls = train_df['make'].dropna().unique()
make_ls
# Out:
# array(['isuzu', 'toyota', 'volvo', 'kia', 'mini', 'bmw', 'ssangyong',
#        'byd', 'mercedes-benz', 'aston martin', 'subaru', 'mazda', 'skoda',
#        'honda', 'mitsubishi', 'lexus', 'infiniti', 'volkswagen',
#        'ferrari', 'nissan', 'porsche', 'chevrolet', 'opel', 'daihatsu',
#        'audi', 'suzuki', 'lamborghini', 'hyundai', 'jeep', 'seat', 'mg',
#        'peugeot', 'renault', 'lotus', 'jaguar', 'maserati', 'mclaren',
#        'citroen', 'alfa romeo', 'fiat', 'land rover', 'triumph',
#        'bentley', 'hummer', 'rolls-royce', 'maxus', 'tesla', 'shineray',
#        'hino', 'perodua', 'iveco', 'alpine', 'sokon', 'austin',
#        'golden dragon', 'rover', 'ford', 'cupra', 'ud', 'mitsuoka',
#        'polestar', 'dfsk', 'foton', 'higer', 'scania', 'camc', 'morris',
#        'daimler', 'datsun', 'ds', 'sunbeam', 'proton', 'ruf', 'srm',
#        'chrysler', 'sinotruk', 'yutong', 'valiant', 'ora', 'dodge',
#        'morgan', 'king long', 'bertone', 'td', 'cadillac', 'smart', 'man',
#        'sc', 'range', 'joylong', 'international'], dtype=object)

# %% [markdown]
# https://www.sgcarmart.com/new_cars/index.php

# %%
idx_val = test_df[test_df['make'].isna()].index
test_df.loc[idx_val]
# Out:
#       listing_id                                        title  make   model  \
# 3072     1307974                              KYC V7 Electric  None      v7
# 3475     1306896                              KYC V7 Electric  None      v7
# 5270     1116426                            Tata Daewoo Prima  None  daewoo
# 7061     1327139                          Zhong Tong LCK6107H  None    tong
# 7284     1329792      Saab 9-5 2.0A Vector (COE till 01/2031)  None     9-5
# 8853     1293101  Saab 9-3 Linear 2.0A LPT (COE till 04/2029)  None     9-3
# 9704     1159217         Maybach 62 S Long (COE till 12/2030)  None      62
#
#                                             description  manufactured  \
# 3072  designed with functionality, practicality and ...        2024.0
# 3475                                                 11        2024.0
# 5270                                                NaN        2017.0
# 7061  mint condition zhongtong 45s. maintained with ...        2017.0
# 7284  full loan/bank loan available, superbly well m...        2010.0
# 8853                                                 10        2007.0
# 9704  bose premium stereo system. only 3 units in si...        2011.0
#
#      original_reg_date     reg_date type_of_vehicle  \
# 3072               NaN  04-jun-2024             van
# 3475               NaN  03-jun-2024             van
# 5270               NaN  27-dec-2017           truck
# 7061               NaN  29-dec-2017    bus/mini bus
# 7284               NaN  07-jan-2011    luxury sedan
# 8853               NaN  26-jun-2009    luxury sedan
# 9704               NaN  27-dec-2011    luxury sedan
#
#                                            category  ... dereg_value  \
# 3072  almost new car, premium ad car, electric cars  ...     41152.0
# 3475                  almost new car, electric cars  ...     45329.0
# 5270                premium ad car, low mileage car  ...         NaN
# 7061                                 premium ad car  ...     15177.0
# 7284       coe car, premium ad car, low mileage car  ...     27107.0
# 8853                        coe car, premium ad car  ...     17269.0
# 9704        coe car, rare & exotic, low mileage car  ...     26659.0
#
#        mileage       omv       arf  opc_scheme     lifespan   eco_category  \
# 3072       NaN   27358.0    1368.0         NaN  03-jun-2044  uncategorized
# 3475     100.0   27358.0    1368.0         NaN  02-jun-2044  uncategorized
# 5270   33825.0   98633.0    4932.0         NaN  26-dec-2037  uncategorized
# 7061       NaN  102252.0    5113.0         NaN  28-dec-2037  uncategorized
# 7284  107000.0   43027.0   43027.0         NaN          NaN  uncategorized
# 8853  169000.0   32206.0   32206.0         NaN          NaN  uncategorized
# 9704    5000.0  765955.0  765955.0         NaN          NaN  uncategorized
#
#                                                features  \
# 3072  driving range on a single charge - 235km to 28...
# 3475  range 235km-285km for 1 charging, torque 220nm...
# 5270                                                NaN
# 7061                                                NaN
# 7284  2.0l inline turbocharged dohc engine, automati...
# 8853  2.0 lpt inline turbocharged dohc engine, auto ...
# 9704  powerful 6.0l v12 twin turbocharged engine pro...
#
#                                             accessories  indicative_price
# 3072  7-inch touchscreen digital infotainment system...               NaN
# 3475  7" touchscreen digital infotainment system w/b...               NaN
# 5270                                                NaN               NaN
# 7061  2 doors, auto transmission, auto luggage compa...               NaN
# 7284  leather seats, sports rims, dual climatic cont...               NaN
# 8853  leather seats, sports rims, good cond tyres, d...               NaN
# 9704  20" signature maybach aluminum rims, multi fun...               NaN
#
# [7 rows x 29 columns]

# %%
make_model_imputer = MakeModelImputer(make_ls)
train_df = make_model_imputer.fit_transform(train_df)
val_df = make_model_imputer.transform(val_df) # 4 rows missing
test_df = make_model_imputer.transform(test_df) # 7 rows missing

# %%
test_df
# Out:
#       listing_id                                             title  \
# 0        1303772                                Honda Vezel 1.5A X
# 1        1323166                Mazda 3 1.6A SP (COE till 10/2027)
# 2        1308405                     MINI Cooper S Countryman 2.0A
# 3        1216706                                Toyota Vios 1.5A G
# 4        1298206                                   Mazda 3 HB 1.5A
# ...          ...                                               ...
# 9995     1315765                                  MG HS 1.5A Turbo
# 9996     1267725        Mercedes-Benz GLA-Class GLA180 Progressive
# 9997     1174990  BMW 3 Series 320i Convertible (COE till 09/2030)
# 9998     1221623                                Kia Cerato 1.6A EX
# 9999     1311711          Subaru Forester 2.5XT (COE till 08/2028)
#
#                make     model  \
# 0             honda     vezel
# 1             mazda         3
# 2              mini    cooper
# 3            toyota      vios
# 4             mazda         3
# ...             ...       ...
# 9995             mg        hs
# 9996  mercedes-benz    gla180
# 9997            bmw       320
# 9998            kia    cerato
# 9999         subaru  forester
#
#                                             description  manufactured  \
# 0                                                  4614        2015.0
# 1     extremely well maintained and in pristine cond...        2007.0
# 2     1 owner! beautiful island blue color! eurokars...        2019.0
# 3     fully agent maintain! genuine low mileage at 5...        2019.0
# 4     workshop check/sta evaluation available. accid...        2015.0
# ...                                                 ...           ...
# 9995  stylish and fuel-efficient  drive at an afford...        2020.0
# 9996  1 owner and low mileage. comes with agent warr...        2022.0
# 9997  just install koni shocks, for the best road ha...        2010.0
# 9998  at dickson, we don't just sell cars, we sell t...        2019.0
# 9999  18" wedssport rims, sti brembo, carbon fibre s...        2008.0
#
#      original_reg_date     reg_date  type_of_vehicle  \
# 0                  NaN  29-apr-2015              suv
# 1                  NaN  26-oct-2007  mid-sized sedan
# 2                  NaN  27-mar-2020       sports car
# 3                  NaN  28-jun-2019  mid-sized sedan
# 4                  NaN  19-nov-2015        hatchback
# ...                ...          ...              ...
# 9995               NaN  30-nov-2020              suv
# 9996               NaN  21-feb-2023              suv
# 9997               NaN  17-dec-2010       sports car
# 9998               NaN  02-mar-2020  mid-sized sedan
# 9999               NaN  25-aug-2008              suv
#
#                                        category  ... dereg_value   mileage  \
# 0                                      parf car  ...      9582.0  112000.0
# 1      coe car, premium ad car, low mileage car  ...     13644.0  120000.0
# 2                                      parf car  ...     54818.0   43000.0
# 3                      parf car, premium ad car  ...     26363.0   53300.0
# 4                      parf car, premium ad car  ...     15197.0  149000.0
# ...                                         ...  ...         ...       ...
# 9995                                   parf car  ...     40705.0   50000.0
# 9996  parf car, premium ad car, low mileage car  ...    104529.0    8500.0
# 9997                                    coe car  ...     22004.0  163955.0
# 9998                                   parf car  ...     28242.0   85473.0
# 9999   coe car, premium ad car, low mileage car  ...     14389.0  155385.0
#
#           omv      arf  opc_scheme  lifespan   eco_category  \
# 0     19229.0   9229.0         NaN       NaN  uncategorized
# 1     14347.0  15782.0         NaN       NaN  uncategorized
# 2     39863.0  47809.0         NaN       NaN  uncategorized
# 3     15573.0  15573.0         NaN       NaN  uncategorized
# 4     18097.0  13097.0         NaN       NaN  uncategorized
# ...       ...      ...         ...       ...            ...
# 9995  19388.0  19388.0         NaN       NaN  uncategorized
# 9996  34087.0  39722.0         NaN       NaN  uncategorized
# 9997  42233.0  42233.0         NaN       NaN  uncategorized
# 9998  14799.0  14799.0         NaN       NaN  uncategorized
# 9999  21692.0  21692.0         NaN       NaN  uncategorized
#
#                                                features  \
# 0     powerful 1.5l i-vtec engine producing 128bhp, ...
# 1     fuel efficient 1.6l 4-cylinder inline 16-valve...
# 2     output of 141kw, 189bhp at 5000rpm to 6000rpm,...
# 3     1.5l 4 cylinder 16 valves dohc vvt-i engine, 7...
# 4     1.5l 4 cylinder inline dohc 16 valves skyactiv...
# ...                                                 ...
# 9995  powered by a 1.5l turbocharged inline-4 cylind...
# 9996  powered by a inline 4 cylinder turbocharged en...
# 9997  2.0l engine, rare convertible. view specs of t...
# 9998  responsive 1.6l 4 cylinders inline 16 valve du...
# 9999  powerful 2.5l turbocharged, boxer engine, auto...
#
#                                             accessories  indicative_price
# 0     pioneer touch screen with reverse camera, 16" ...               NaN
# 1     multi-function steering wheel, keyless entry, ...               NaN
# 2     18" sports rims, sports leather seats, navigat...               NaN
# 3     push start button, toyota factory player, reve...               NaN
# 4     factory fitted audio with audio & multi functi...               NaN
# ...                                                 ...               ...
# 9995  17-inch rims, led drls, 10" color touch screen...               NaN
# 9996  factory 10.25" mbux infotainment system with a...               NaN
# 9997  new upgraded steering, android player, flawles...               NaN
# 9998  3 day money-back, certified cars, one-year war...               NaN
# 9999  original leather seats, aftermarket headunit, ...               NaN
#
# [10000 rows x 29 columns]

# %% [markdown]
# ### Cylinder count extractor

# %%
cylinder_count_extractor = CylinderExtractor()
train_df = cylinder_count_extractor.transform(train_df)
val_df = cylinder_count_extractor.transform(val_df)

# %%
train_df.head()
# Out:
#        listing_id                                title    make   model  \
# 23311     1260733                          Isuzu NPR85   isuzu   npr85
# 23623     1289505  Honda Fit 1.3A G (COE till 06/2024)   honda     fit
# 1020      1316182                   Toyota Sienta 1.5A  toyota  sienta
# 12645     1310514                Volvo V40 T4 Momentum   volvo     v40
# 1533      1247893                  Kia Carens 2.0A GDI     kia  carens
#
#                                              description  manufactured  \
# 23311  cheapest in the market! 14 feet full canopy wi...        2019.0
# 23623                                                200        2009.0
# 1020   non phv. excellent condition. 100% accident fr...        2018.0
# 12645  well maintained! the safety, reliable and dura...        2018.0
# 1533   rare 1 owner unit! low km done! fully maintain...        2015.0
#
#       original_reg_date     reg_date type_of_vehicle  \
# 23311               NaN  01-jul-2020           truck
# 23623               NaN  12-aug-2009       hatchback
# 1020                NaN  28-may-2018             mpv
# 12645               NaN  30-aug-2019       hatchback
# 1533                NaN  18-nov-2015             mpv
#
#                        category  ...     lifespan   eco_category  \
# 23311            premium ad car  ...  30-jun-2040  uncategorized
# 23623                   coe car  ...          NaN  uncategorized
# 1020   parf car, premium ad car  ...          NaN  uncategorized
# 12645                  parf car  ...          NaN  uncategorized
# 1533                   parf car  ...          NaN  uncategorized
#
#                                                 features  \
# 23311            view specs of the isuzu n series diesel
# 23623                        view specs of the honda fit
# 1020   1.5l dohc 16v vvt-i engine, 7 speed cvt-i auto...
# 12645  powerful 2.0l 4 cylinder inline 16 valve turbo...
# 1533                        view specs of the kia carens
#
#                                              accessories  indicative_price  \
# 23311                                                NaN               NaN
# 23623                                                NaN               NaN
# 1020   factory touchscreen audio system with reverse ...               NaN
# 12645  keyless entry/start, cruise control, auto head...               NaN
# 1533   upgraded headunit with reverse camera! factory...               NaN
#
#          price  reg_date_dt  reg_date_year  reg_date_month  cylinder_cnt
# 23311  89800.0   2020-07-01           2020               7           NaN
# 23623    700.0   2009-08-12           2009               8           NaN
# 1020   64800.0   2018-05-28           2018               5           NaN
# 12645  92800.0   2019-08-30           2019               8           4.0
# 1533   32888.0   2015-11-18           2015              11           NaN
#
# [5 rows x 34 columns]

# %% [markdown]
# ### Impute cylinder data using make, model

# %%
cylinder_imputer = CylinderImputer()
train_df = cylinder_imputer.fit_transform(train_df) # 1479 rows missing
val_df = cylinder_imputer.transform(val_df) # 334 rows missing

# Many rows are missing, impute using median values
imputer = SimpleImputer(strategy='median')
train_df['cylinder_cnt'] = imputer.fit_transform(train_df[['cylinder_cnt']])

val_df['cylinder_cnt'] = imputer.transform(val_df[['cylinder_cnt']])

# %%
# idx_val = train_df[train_df['cylinder_cnt'].isna()].index
# train_df.loc[idx_val]
# Out:
# Empty DataFrame
# Columns: [listing_id, title, make, model, description, manufactured, original_reg_date, reg_date, type_of_vehicle, category, transmission, curb_weight, power, fuel_type, engine_cap, no_of_owners, depreciation, coe, road_tax, dereg_value, mileage, omv, arf, opc_scheme, lifespan, eco_category, features, accessories, indicative_price, price, reg_date_dt, reg_date_year, reg_date_month, cylinder_cnt]
# Index: []
#
# [0 rows x 34 columns]

# %%
# val_df.loc[idx_val]

# %% [markdown]
# ### Impute using LTA omv data

# %%
csv_filename = r'./dataset/lta_omv_data.csv'

# %%
if os.path.exists(csv_filename):
    df_lta_car_data = pd.read_csv(csv_filename)
else:
    result_ls = get_lta_omv_data(2002, 2025)
    df_lta_car_data = preprocess_lta_omv_data(result_ls)
    df_lta_car_data.to_csv(csv_filename)

# %%
# lta_data_imputer = LTADataImputer(df_lta_car_data)

# %%
idx_val = val_df[val_df['omv'].isna()].index
val_df.loc[idx_val]
# Out:
# Empty DataFrame
# Columns: [listing_id, title, make, model, description, manufactured, original_reg_date, reg_date, type_of_vehicle, category, transmission, curb_weight, power, fuel_type, engine_cap, no_of_owners, depreciation, coe, road_tax, dereg_value, mileage, omv, arf, opc_scheme, lifespan, eco_category, features, accessories, indicative_price, price, reg_date_dt, reg_date_year, reg_date_month, cylinder_cnt]
# Index: []
#
# [0 rows x 34 columns]

# %%
train_df = lta_data_imputer.transform(train_df) # before transform: 49 rows missing, after transform: 24 rows missing
val_df = lta_data_imputer.transform(val_df) # before transform: 15 rows missing, after transform: 9 rows missing

imputer = SimpleImputer(strategy='median')
train_df['omv'] = imputer.fit_transform(train_df[['omv']])
val_df['omv'] = imputer.transform(val_df[['omv']])

# %% [markdown]
# ### Parse category

# %%
train_df
# Out:
#        listing_id                                           title     make  \
# 23311     1260733                                     Isuzu NPR85    isuzu
# 23623     1289505             Honda Fit 1.3A G (COE till 06/2024)      NaN
# 1020      1316182                              Toyota Sienta 1.5A   toyota
# 12645     1310514                           Volvo V40 T4 Momentum    volvo
# 1533      1247893                             Kia Carens 2.0A GDI      kia
# ...           ...                                             ...      ...
# 21575     1330095                               BMW 3 Series 318i      bmw
# 5390      1300273                       Nissan Qashqai 1.2A DIG-T   nissan
# 860       1316903                                 Honda Jazz 1.3A    honda
# 15795     1329593                                 Ferrari 488 GTB  ferrari
# 23654     1321619  BMW 6 Series 630i Cabriolet (COE till 08/2028)      bmw
#
#          model                                        description  \
# 23311    npr85  cheapest in the market! 14 feet full canopy wi...
# 23623      fit                                                200
# 1020    sienta  non phv. excellent condition. 100% accident fr...
# 12645      v40  well maintained! the safety, reliable and dura...
# 1533    carens  rare 1 owner unit! low km done! fully maintain...
# ...        ...                                                ...
# 21575     318i                                                  0
# 5390   qashqai  no repairs needed, buy and drive as it is! one...
# 860       jazz  1 owner, maintain by honda kah motor, at dicks...
# 15795      488  ital unit with warranty till dec 2024. fully s...
# 23654     630i                                                  0
#
#        manufactured original_reg_date     reg_date type_of_vehicle  \
# 23311        2019.0               NaN  01-jul-2020           truck
# 23623        2009.0               NaN  12-aug-2009       hatchback
# 1020         2018.0               NaN  28-may-2018             mpv
# 12645        2018.0               NaN  30-aug-2019       hatchback
# 1533         2015.0               NaN  18-nov-2015             mpv
# ...             ...               ...          ...             ...
# 21575        2015.0               NaN  26-feb-2016    luxury sedan
# 5390         2016.0               NaN  17-jun-2016             suv
# 860          2019.0               NaN  10-jul-2019       hatchback
# 15795        2016.0               NaN  03-nov-2016      sports car
# 23654        2008.0               NaN  29-aug-2008      sports car
#
#                                                 category  ... opc_scheme  \
# 23311                                     premium ad car  ...        NaN
# 23623                                            coe car  ...        NaN
# 1020                            parf car, premium ad car  ...        NaN
# 12645                                           parf car  ...        NaN
# 1533                                            parf car  ...        NaN
# ...                                                  ...  ...        ...
# 21575  parf car, consignment car, sgcarmart warranty ...  ...        NaN
# 5390                            parf car, premium ad car  ...        NaN
# 860                                             parf car  ...        NaN
# 15795  parf car, direct owner sale, rare & exotic, lo...  ...        NaN
# 23654                            coe car, premium ad car  ...        NaN
#
#           lifespan   eco_category  \
# 23311  30-jun-2040  uncategorized
# 23623          NaN  uncategorized
# 1020           NaN  uncategorized
# 12645          NaN  uncategorized
# 1533           NaN  uncategorized
# ...            ...            ...
# 21575          NaN  uncategorized
# 5390           NaN  uncategorized
# 860            NaN  uncategorized
# 15795          NaN  uncategorized
# 23654          NaN  uncategorized
#
#                                                 features  \
# 23311            view specs of the isuzu n series diesel
# 23623                        view specs of the honda fit
# 1020   1.5l dohc 16v vvt-i engine, 7 speed cvt-i auto...
# 12645  powerful 2.0l 4 cylinder inline 16 valve turbo...
# 1533                        view specs of the kia carens
# ...                                                  ...
# 21575  powered by 134bhp and 1.5l twinpower turbochar...
# 5390   1.2l 4 cylinder inline 16 valve dohc turbochar...
# 860    1.3l i-vtec engine, cvt auto transmission with...
# 15795  a ferrari 488 gtb needs no extra words. view s...
# 23654  3.0 inline 6 engine, 268bhp, with 315nm of tor...
#
#                                              accessories  indicative_price  \
# 23311                                                NaN               NaN
# 23623                                                NaN               NaN
# 1020   factory touchscreen audio system with reverse ...               NaN
# 12645  keyless entry/start, cruise control, auto head...               NaN
# 1533   upgraded headunit with reverse camera! factory...               NaN
# ...                                                  ...               ...
# 21575  upgraded rims, brembo brakes, carbon steering,...               NaN
# 5390   auto headlights, multi function steering wheel...               NaN
# 860    3 day money back, certified cars, one year war...               NaN
# 15795  cf rear air ducts, cf under door cover,!lifter...               NaN
# 23654  original bmw audio, am/multi function steering...               NaN
#
#           price  reg_date_dt  reg_date_year  reg_date_month
# 23311   89800.0   2020-07-01           2020               7
# 23623     700.0   2009-08-12           2009               8
# 1020    64800.0   2018-05-28           2018               5
# 12645   92800.0   2019-08-30           2019               8
# 1533    32888.0   2015-11-18           2015              11
# ...         ...          ...            ...             ...
# 21575   37800.0   2016-02-26           2016               2
# 5390    33688.0   2016-06-17           2016               6
# 860     73800.0   2019-07-10           2019               7
# 15795  649900.0   2016-11-03           2016              11
# 23654   53888.0   2008-08-29           2008               8
#
# [20000 rows x 33 columns]
